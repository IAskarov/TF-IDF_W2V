# %% [markdown]
# # Импорт библиотек

# %%
import numpy as np       # линейная алгебра
import pandas as pd      # работа с табличными данными
import os                # работа с операционной системой
import string            # работа со строковыми значениями
import re                # работа с регулярными выражениями

import nltk                               # работа с естественным языком           
from nltk.corpus import stopwords         # список стоп-слов

from sklearn.feature_extraction.text import TfidfVectorizer          # Преобразование тектов в TFIDF-матрицу
from sklearn.metrics.pairwise import cosine_similarity               # Метрика измерения косинусного расстояния между векторами

import gensim                                        # Работа с моделями W2V
import gensim.downloader
from gensim.models import word2vec,KeyedVectors

# %% [markdown]
# # Функции

# %%
# Функция удаления символов из текста
def remove_chars_from_text(text_, chars_):
    return "".join([ch for ch in text_ if ch not in chars_])


# Функция удаления стоп-слов
def clear_stop_words(text_, stopwords_):
    return ' '.join([word for word in str(text_).split() if word not in stopwords_])


# Функция удаления HTML-ссылок
def remove_urls(text_):
    url_remove = re.compile(r'https?://\S+|www\.\S+')
    return url_remove.sub(r' ', text_)


# Функция удаления URL-ссылок
def remove_html(text_):
    html=re.compile(r'<.*?>')
    return html.sub(r' ',text_)


# Функция предобработки текста
def text_preproc(
    series_,              # На вход получает данные в формате pandas.Series
    spec_chars_,          # список спец-символов, которые необходимо вычистить
    stopwords_            # список стоп-слов, которые необходимо убрать из текста
):          
    
    # Удаляем URL-ссылки
    series_ = series_.apply(lambda x:remove_urls(x))

    # Удаляем HTML-ссылки
    series_ = series_.apply(lambda x: remove_html(x))

    # Переводим символы к нижнему регистру
    series_ = series_.apply(lambda x: x.lower())

    # Удаляем пунктуацию и спец-символы
    series_ = series_.apply(lambda x: remove_chars_from_text(x, spec_chars_))

    # Удаляем цифры
    series_ = series_.apply(lambda x: remove_chars_from_text(x, string.digits))

    # Убираем лишние пробелы
    series_ = series_.apply(lambda x: ' '.join(x.split()))
    
    # Убираем стоп-слова
    series_ = series_.apply(lambda x: clear_stop_words(x, stopwords_))
    
    return series_

# %% [markdown]
# # Загрузка и обзор данных

# %%
# Загрузим данные
df = pd.read_csv('sample-data.csv')

# Сводная информация о загруженном датасете
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           500 non-null    int64
#  1   description  500 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 7.9+ KB

# %%
# Пример данных
df.sample(10)
# Out:
#       id                                        description
# 293  294  Inga shortie - Short boards and short shorts l...
# 273  274  Torrentshell jkt - Tropical rain forests share...
# 94    95  Mountain island t-shirt - For those who aspire...
# 76    77  L/s rashguard - The 30-UPF fabric of our Long-...
# 209  210  Nine trails vest - Simplicity in action - this...
# 233  234  Vitaliti dress - The ocean has had its way wit...
# 154  155  Active hipster - While the perfect life might ...
# 49    50  Guidewater duffle - max - For serious angling ...
# 345  346  Versatiliti tee - A free-moving, breathable an...
# 12    13  Beach bucket - Whenever you're at the junction...

# %%
# Посмотрим пример текста в описании товара
df['description'][0]
# Out:
# 'Active classic boxers - There\'s a reason why our boxers are a cult favorite - they keep their cool, especially in sticky situations. The quick-drying, lightweight underwear takes up minimal space in a travel pack. An exposed, brushed waistband offers next-to-skin softness, five-panel construction with a traditional boxer back for a classic fit, and a functional fly. Made of 3.7-oz 100% recycled polyester with moisture-wicking performance. Inseam (size M) is 4 1/2". Recyclable through the Common Threads Recycling Program.<br><br><b>Details:</b><ul> <li>"Silky Capilene 1 fabric is ultralight, breathable and quick-to-dry"</li> <li>"Exposed, brushed elastic waistband for comfort"</li> <li>5-panel construction with traditional boxer back</li> <li>"Inseam (size M) is 4 1/2"""</li></ul><br><br><b>Fabric: </b>3.7-oz 100% all-recycled polyester with Gladiodor natural odor control for the garment. Recyclable through the Common Threads Recycling Program<br><br><b>Weight: </b>99 g (3.5 oz)<br><br>Made in Mexico.'

# %% [markdown]
# Текст содержит таги форматирования и спец-символы. Перед преобразованием в векторное представление тексты необходимо от них почистить.
#
# Далее нужно удалить цифры, перевести все символы в нижний регистр и удалить стоп-слова.

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Выведем стандартный перечень знаков препинания, входящий в библиотеку string
print('Базовый набор знаков препинания:', string.punctuation)

# Загрузим справочник английских стоп-слов 
stopwords_english = stopwords.words('english')

# Выведем базовый список стоп-слов
print('Базовый список стоп-слов:', stopwords_english)

# Расширим базовый список стоп-слов единицами измерения
stopwords_english.extend(['g', 'oz'])
# Out:
# Базовый набор знаков препинания: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# Базовый список стоп-слов: ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# Сохраним в переменную список символов пунктуации
spec_chars = string.punctuation

# Проведем предобработку текста поля 'description'
df['description'] = text_preproc(df['description'], spec_chars, stopwords_english)

# Проверим результат предобратобки
df['description'][0]
# Out:
# 'active classic boxers theres reason boxers cult favorite keep cool especially sticky situations quickdrying lightweight underwear takes minimal space travel pack exposed brushed waistband offers nexttoskin softness fivepanel construction traditional boxer back classic fit functional fly made recycled polyester moisturewicking performance inseam size recyclable common threads recycling program details silky capilene fabric ultralight breathable quicktodry exposed brushed elastic waistband comfort panel construction traditional boxer back inseam size fabric allrecycled polyester gladiodor natural odor control garment recyclable common threads recycling program weight made mexico'

# %% [markdown]
# # Векторизация текстов TFIDF

# %%
# Инициализируем токенайзер для преобразования каждого текста в вектор. Максимальный размер словаря 25000 слов
tfidf_vectorizer = TfidfVectorizer(binary=True, max_features=25000)

# Преобразуем очищенные тексты в матрицы TFIDF
tfidf_embedings = tfidf_vectorizer.fit_transform(df['description'])

# Проверяем размерность полученного массива
tfidf_embedings.shape
# Out:
# (500, 5051)

# %%
# Вычисляем попарно косинусное расстояние между векторами в матрице
cos_matrix = cosine_similarity(tfidf_embedings)

# Находим индексы значений косинусного расстояния больше 0.7
pair_indexes = np.transpose(np.nonzero(cos_matrix > 0.8))

# Перебираем пары индексов
for x in pair_indexes:
    
    # Если индексы не равны друг другу, что означает, что сравнивались описания разных товаров
    if x[0] != x[1]:
        
        # Выводим пары описаний товаров
        print(df['description'][x])

# %% [markdown]
# # Векторизация текстов W2V

# %%
# Загружаем предобученную модель
word_vectors = gensim.downloader.load("word2vec-google-news-300")
# Out:
# [=================================================-] 99.8% 1659.8/1662.8MB downloaded

# %%
# Создаем пустой DataFrame для эмбедингов текстов
docs_vectors = pd.DataFrame()

# Идем по текстам
for doc in df['description']:
    
    # Создаем пустой DataFrame для хранения векторов слов текста
    temp = pd.DataFrame()
    
    # Идем по словам в тексте
    for word in doc.split(' '):
        
        try:
            # Векторизуем слово с использованием предобученной модели W2V
            word_vec = word_vectors[word]

            # Добавляем вектор слова в DF
            temp = temp.append(pd.Series(word_vec), ignore_index = True)
            
        except:
            pass
        
    # Вычисляем вектор текста усредняя массив векторов слов
    doc_vector = temp.mean()
    
    # Добавляем вектор текста в DF эмбедингов текстов
    docs_vectors = docs_vectors.append(doc_vector, ignore_index = True)

# Размерность DF эмбедингов текстов    
docs_vectors.shape

# %%
# Примеры векторизованных текстов
docs_vectors.sample(5)
# Out:
#           0         1         2         3         4         5         6    \
# 281 -0.014215  0.029400 -0.068109  0.071323 -0.076661 -0.010374  0.031660
# 311 -0.036820  0.088027  0.012051  0.081767 -0.074823 -0.003016  0.022253
# 332 -0.041864  0.085060 -0.008363  0.093516 -0.074078  0.056390  0.054124
# 325 -0.011082  0.023059 -0.028724  0.113606 -0.061977 -0.025908  0.051195
# 155 -0.036085  0.011818 -0.076087 -0.007148 -0.067861 -0.009624  0.039668
#
#           7         8         9    ...       290       291       292  \
# 281 -0.069588  0.076656  0.084322  ... -0.070450 -0.019910 -0.109974
# 311 -0.078171  0.074554  0.137727  ... -0.107171 -0.009779 -0.090762
# 332 -0.097302  0.042922  0.106663  ... -0.094520 -0.016868 -0.052246
# 325 -0.085390  0.074606  0.115341  ... -0.096298  0.019643 -0.009331
# 155 -0.088894  0.037891  0.058915  ... -0.074969  0.065057 -0.059466
#
#           293       294       295       296       297       298       299
# 281  0.031777 -0.010613 -0.034714  0.075309 -0.001497  0.024177  0.054152
# 311 -0.018926 -0.024475 -0.062446  0.069326 -0.069496  0.065305  0.011553
# 332 -0.028333  0.032556 -0.056651  0.128946 -0.077091  0.052747 -0.043324
# 325 -0.012137  0.005573 -0.043899  0.098089 -0.023705  0.037224  0.040942
# 155 -0.015821 -0.047361 -0.013159  0.105062  0.003509  0.004253  0.034020
#
# [5 rows x 300 columns]

# %%
# Вычисляем попарно косинусное расстояние между векторами в матрице, округляем значения до 5 знака после запятой
cos_matrix_w2v = np.around(cosine_similarity(docs_vectors), 5)
cos_matrix_w2v
# Out:
# array([[1.     , 0.924  , 0.87996, ..., 0.87295, 0.87712, 0.89696],
#        [0.924  , 1.     , 0.94335, ..., 0.8839 , 0.88246, 0.88969],
#        [0.87996, 0.94335, 1.     , ..., 0.86466, 0.83776, 0.85104],
#        ...,
#        [0.87295, 0.8839 , 0.86466, ..., 1.     , 0.86754, 0.85358],
#        [0.87712, 0.88246, 0.83776, ..., 0.86754, 1.     , 0.94413],
#        [0.89696, 0.88969, 0.85104, ..., 0.85358, 0.94413, 1.     ]],
#       dtype=float32)

# %%
# Находим пары векторов, косинусное расстояние между которыми больше 0.985
pair_indexes_w2v = np.transpose(np.nonzero(cos_matrix_w2v > 0.985))

# Перебираем пары индексов
for x in pair_indexes_w2v:
    
    # Если индексы не равны друг другу, что означает, что сравнивались описания разных товаров
    if x[0] != x[1]:
        
        # Выводим пары похожих описаний товаров
        print(df['description'][x])
# Out:
# 3      alpine guide pants skin climb ice switch rock ...
# 158    alpine guide pants skin climb ice switch rock ...
# Name: description, dtype: object
# 4      alpine wind jkt high ridges steep ice anything...
# 307    alpine wind jkt high ridges steep ice anything...
# Name: description, dtype: object
# 7      print banded betina btm fullest coverage botto...
# 219    solid betina btm fullest coverage bottoms beti...
# Name: description, dtype: object
# 14    borderless shorts go forward others cringe bor...
# 15    borderless shorts one summertimes gifts chance...
# Name: description, dtype: object
# 15    borderless shorts one summertimes gifts chance...
# 14    borderless shorts go forward others cringe bor...
# Name: description, dtype: object
# 19     cap graphic tshirt tee made lightestweight cap...
# 339    cap graphic tshirt elegant union graceful desi...
# Name: description, dtype: object
# 24     cap bottoms sufferfests like grand january pai...
# 175    cap bottoms world consists granite frozen plac...
# Name: description, dtype: object
# 26    compound cargo pants long ultimate doeverythin...
# 27    compound cargo pants reg ultimate doeverything...
# Name: description, dtype: object
# 26     compound cargo pants long ultimate doeverythin...
# 451    compound cargo pants short ultimate doeverythi...
# Name: description, dtype: object
# 27    compound cargo pants reg ultimate doeverything...
# 26    compound cargo pants long ultimate doeverythin...
# Name: description, dtype: object
# 27     compound cargo pants reg ultimate doeverything...
# 451    compound cargo pants short ultimate doeverythi...
# Name: description, dtype: object
# 31     custodian pants long graveyard shift advantage...
# 461    custodian pants reg graveyard shift advantages...
# Name: description, dtype: object
# 31     custodian pants long graveyard shift advantage...
# 462    custodian pants short graveyard shift advantag...
# Name: description, dtype: object
# 34     sweater vest impossible confuse sweater vests ...
# 281    sweater vest impossible confuse sweater vests ...
# Name: description, dtype: object
# 36     duck pants long essential wear splitting logs ...
# 480    duck pants reg essential wear splitting logs d...
# Name: description, dtype: object
# 36     duck pants long essential wear splitting logs ...
# 481    duck pants short essential wear splitting logs...
# Name: description, dtype: object
# 41     freewheeler sturdy wheeled bag holds weeks wor...
# 420    freewheeler max like storage locker wheels cav...
# Name: description, dtype: object
# 48     great divider standing waves bluewater wind ch...
# 133    sub divider tough water resistant great divide...
# Name: description, dtype: object
# 51     guidewater shorts everything love guidewater p...
# 443    guidewater pants drift boat flats skiff spring...
# Name: description, dtype: object
# 57    logo tshirt softwearing ringspun organic cotto...
# 62    flying fish tshirt softwearing ringspun organi...
# Name: description, dtype: object
# 57    logo tshirt softwearing ringspun organic cotto...
# 63    gpiw classic tshirt softwearing ringspun organ...
# Name: description, dtype: object
# 57    logo tshirt softwearing ringspun organic cotto...
# 64    live simply guitar tshirt softwearing ringspun...
# Name: description, dtype: object
# 57     logo tshirt softwearing ringspun organic cotto...
# 432    girls live simply seal tshirt softwearing ring...
# Name: description, dtype: object
# 62    flying fish tshirt softwearing ringspun organi...
# 57    logo tshirt softwearing ringspun organic cotto...
# Name: description, dtype: object
# 62    flying fish tshirt softwearing ringspun organi...
# 63    gpiw classic tshirt softwearing ringspun organ...
# Name: description, dtype: object
# 62    flying fish tshirt softwearing ringspun organi...
# 64    live simply guitar tshirt softwearing ringspun...
# Name: description, dtype: object
# 62     flying fish tshirt softwearing ringspun organi...
# 431    girls live simply deer tshirt softwearing ring...
# Name: description, dtype: object
# 62     flying fish tshirt softwearing ringspun organi...
# 432    girls live simply seal tshirt softwearing ring...
# Name: description, dtype: object
# 63    gpiw classic tshirt softwearing ringspun organ...
# 57    logo tshirt softwearing ringspun organic cotto...
# Name: description, dtype: object
# 63    gpiw classic tshirt softwearing ringspun organ...
# 62    flying fish tshirt softwearing ringspun organi...
# Name: description, dtype: object
# 63    gpiw classic tshirt softwearing ringspun organ...
# 64    live simply guitar tshirt softwearing ringspun...
# Name: description, dtype: object
# 63     gpiw classic tshirt softwearing ringspun organ...
# 431    girls live simply deer tshirt softwearing ring...
# Name: description, dtype: object
# 63     gpiw classic tshirt softwearing ringspun organ...
# 432    girls live simply seal tshirt softwearing ring...
# Name: description, dtype: object
# 64    live simply guitar tshirt softwearing ringspun...
# 57    logo tshirt softwearing ringspun organic cotto...
# Name: description, dtype: object
# 64    live simply guitar tshirt softwearing ringspun...
# 62    flying fish tshirt softwearing ringspun organi...
# Name: description, dtype: object
# 64    live simply guitar tshirt softwearing ringspun...
# 63    gpiw classic tshirt softwearing ringspun organ...
# Name: description, dtype: object
# 64     live simply guitar tshirt softwearing ringspun...
# 431    girls live simply deer tshirt softwearing ring...
# Name: description, dtype: object
# 64     live simply guitar tshirt softwearing ringspun...
# 432    girls live simply seal tshirt softwearing ring...
# Name: description, dtype: object
# 71     live simply deer tshirt adaptability simply ma...
# 333    live simply deer tshirt adaptability simply ma...
# Name: description, dtype: object
# 72     live simply guitar tshirt live life unplugged ...
# 334    live simply guitar tshirt live life unplugged ...
# Name: description, dtype: object
# 76     ls rashguard upf fabric longsleeved rashguard ...
# 360    ss rashguard upf fabric shortsleeved rashguard...
# Name: description, dtype: object
# 81     lw r jkt high deck warbonnet peak immaculate w...
# 379    lw r jkt high deck warbonnet peak immaculate w...
# Name: description, dtype: object
# 84     jkt made thrive thin technical climbs full alp...
# 196    jkt made thrive thin technical climbs full alp...
# Name: description, dtype: object
# 86    merino crew day packed decisions ones easy wor...
# 87    merino tshirt bus ride tlachichuca packs bodie...
# Name: description, dtype: object
# 87    merino tshirt bus ride tlachichuca packs bodie...
# 86    merino crew day packed decisions ones easy wor...
# Name: description, dtype: object
# 87     merino tshirt bus ride tlachichuca packs bodie...
# 406    merino crew soft longsleeved tee work sweat bi...
# Name: description, dtype: object
# 88    merino polo feel bohemian look least get foot ...
# 89    merino tshirt stay calm collected amid frenzy ...
# Name: description, dtype: object
# 88     merino polo feel bohemian look least get foot ...
# 406    merino crew soft longsleeved tee work sweat bi...
# Name: description, dtype: object
# 89    merino tshirt stay calm collected amid frenzy ...
# 88    merino polo feel bohemian look least get foot ...
# Name: description, dtype: object
# 89     merino tshirt stay calm collected amid frenzy ...
# 406    merino crew soft longsleeved tee work sweat bi...
# Name: description, dtype: object
# 95     nine trails jkt somewhere bridger ridge run no...
# 280    nine trails jkt nine trails jacket women whose...
# Name: description, dtype: object
# 96     nine trails shorts view trails sanctuary runni...
# 208    nine trails shorts mountain biking trail runni...
# Name: description, dtype: object
# 106    rain shadow pants light enough afterthought do...
# 350    rain shadow pants light enough afterthought do...
# Name: description, dtype: object
# 107    reg fit organic ctn jeanslong organic cotton d...
# 108    reg fit organic ctn jeansreg organic cotton de...
# Name: description, dtype: object
# 107    reg fit organic ctn jeanslong organic cotton d...
# 389    reg fit organic ctn jeansshort organic cotton ...
# Name: description, dtype: object
# 108    reg fit organic ctn jeansreg organic cotton de...
# 107    reg fit organic ctn jeanslong organic cotton d...
# Name: description, dtype: object
# 108    reg fit organic ctn jeansreg organic cotton de...
# 389    reg fit organic ctn jeansshort organic cotton ...
# Name: description, dtype: object
# 109    relax fit organic ctn jeansshor everyday goto ...
# 390    relax fit organic ctn jeanslong everyday goto ...
# Name: description, dtype: object
# 109    relax fit organic ctn jeansshor everyday goto ...
# 391    relax fit organic ctn jeansreg everyday goto r...
# Name: description, dtype: object
# 112    riverwalker felt high water slick bedrock cobb...
# 113    riverwalker studded high water slick bedrock c...
# Name: description, dtype: object
# 112    riverwalker felt high water slick bedrock cobb...
# 397    marlwalker stalking coral flats tough feet eve...
# Name: description, dtype: object
# 112    riverwalker felt high water slick bedrock cobb...
# 419    riverwalker sticky high water slick bedrock co...
# Name: description, dtype: object
# 113    riverwalker studded high water slick bedrock c...
# 112    riverwalker felt high water slick bedrock cobb...
# Name: description, dtype: object
# 113    riverwalker studded high water slick bedrock c...
# 397    marlwalker stalking coral flats tough feet eve...
# Name: description, dtype: object
# 113    riverwalker studded high water slick bedrock c...
# 419    riverwalker sticky high water slick bedrock co...
# Name: description, dtype: object
# 117    shop pants reg home truck inside shop pants ma...
# 118    shop pants short home truck inside shop pants ...
# Name: description, dtype: object
# 117    shop pants reg home truck inside shop pants ma...
# 349    shop pants long home truck inside shop pants m...
# Name: description, dtype: object
# 118    shop pants short home truck inside shop pants ...
# 117    shop pants reg home truck inside shop pants ma...
# Name: description, dtype: object
# 118    shop pants short home truck inside shop pants ...
# 349    shop pants long home truck inside shop pants m...
# Name: description, dtype: object
# 119    simple guide jkt skinin headlamp summit noon f...
# 215    simple guide jkt skinin headlamp summit noon f...
# Name: description, dtype: object
# 133    sub divider tough water resistant great divide...
# 48     great divider standing waves bluewater wind ch...
# Name: description, dtype: object
# 140    torrentshell pants theyre lightweight waterpro...
# 274    torrentshell pants theyre lightweight waterpro...
# Name: description, dtype: object
# 142    traverse jkt training routine number bicycle i...
# 231    traverse jkt sun set air cold three rugged mil...
# Name: description, dtype: object
# 152    watermaster waders long blackberries barbwire ...
# 153    watermaster waders short blackberries barbwire...
# Name: description, dtype: object
# 152    watermaster waders long blackberries barbwire ...
# 354    watermaster waders king blackberries barbwire ...
# Name: description, dtype: object
# 152    watermaster waders long blackberries barbwire ...
# 366    watermaster waders reg blackberries barbwire b...
# Name: description, dtype: object
# 152    watermaster waders long blackberries barbwire ...
# 454    guidewater waders king built guidewater waders...
# Name: description, dtype: object
# 152    watermaster waders long blackberries barbwire ...
# 467    guidewater waders reg built guidewater waders ...
# Name: description, dtype: object
# 153    watermaster waders short blackberries barbwire...
# 152    watermaster waders long blackberries barbwire ...
# Name: description, dtype: object
# 153    watermaster waders short blackberries barbwire...
# 354    watermaster waders king blackberries barbwire ...
# Name: description, dtype: object
# 153    watermaster waders short blackberries barbwire...
# 366    watermaster waders reg blackberries barbwire b...
# Name: description, dtype: object
# 153    watermaster waders short blackberries barbwire...
# 454    guidewater waders king built guidewater waders...
# Name: description, dtype: object
# 153    watermaster waders short blackberries barbwire...
# 467    guidewater waders reg built guidewater waders ...
# Name: description, dtype: object
# 158    alpine guide pants skin climb ice switch rock ...
# 3      alpine guide pants skin climb ice switch rock ...
# Name: description, dtype: object
# 172    cap bottoms simulclimbing final pitches beat d...
# 495    cap bottoms cut loose maddening crowds search ...
# Name: description, dtype: object
# 175    cap bottoms world consists granite frozen plac...
# 24     cap bottoms sufferfests like grand january pai...
# Name: description, dtype: object
# 178    sweater theres much see feet chasm view bivy v...
# 472    sweater theres much see feet chasm view bivy v...
# Name: description, dtype: object
# 183    guide jkt sharp granite sticky verglas untrack...
# 437    guide jkt sharp granite sticky verglas untrack...
# Name: description, dtype: object
# 187    intercontinental pants long youll like flatter...
# 304    intercontinental pants reg youll like flatteri...
# Name: description, dtype: object
# 196    jkt made thrive thin technical climbs full alp...
# 84     jkt made thrive thin technical climbs full alp...
# Name: description, dtype: object
# 199    merino graphic tshirt feels good laugh lightes...
# 200    merino tank finespun cool enough lower tempera...
# Name: description, dtype: object
# 199    merino graphic tshirt feels good laugh lightes...
# 259    merino crew lightest merino layer silkysoft ye...
# Name: description, dtype: object
# 199    merino graphic tshirt feels good laugh lightes...
# 264    merino tshirt soft worth lingering lightest me...
# Name: description, dtype: object
# 200    merino tank finespun cool enough lower tempera...
# 199    merino graphic tshirt feels good laugh lightes...
# Name: description, dtype: object
# 200    merino tank finespun cool enough lower tempera...
# 259    merino crew lightest merino layer silkysoft ye...
# Name: description, dtype: object
# 200    merino tank finespun cool enough lower tempera...
# 264    merino tshirt soft worth lingering lightest me...
# Name: description, dtype: object
# 203    micro puff vest many alpine shiverfests leave ...
# 415    micro puff vest many alpine shiverfests leave ...
# Name: description, dtype: object
# 208    nine trails shorts mountain biking trail runni...
# 96     nine trails shorts view trails sanctuary runni...
# Name: description, dtype: object
# 209    nine trails vest simplicity action vest protec...
# 363    nine trails vest simplicity action vest protec...
# Name: description, dtype: object
# 210    r jkt modern mountain staple adaptable r jacke...
# 380    r jkt modern mountain staple adaptable r jacke...
# Name: description, dtype: object
# 211    rain shadow jkt staying inside isnt way stay d...
# 381    rain shadow jkt staying inside isnt way stay d...
# Name: description, dtype: object
# 214    serenity tights long soft stretchy unrestricte...
# 246    serenity tights soft stretchy unrestricted mob...
# Name: description, dtype: object
# 215    simple guide jkt skinin headlamp summit noon f...
# 119    simple guide jkt skinin headlamp summit noon f...
# Name: description, dtype: object
# 216    simple guide pants trip patagonia one pair pan...
# 352    simple guide pants staple rock ice mixed climb...
# Name: description, dtype: object
# 218    solid adour btm adours feature scooped lowrise...
# 290    print adour btm adours slightly scooped lowris...
# Name: description, dtype: object
# 219    solid betina btm fullest coverage bottoms beti...
# 7      print banded betina btm fullest coverage botto...
# Name: description, dtype: object
# 221    solid bibiana top athletic bibiana tops racerb...
# 241    print bibiana top athletic bibiana tops racerb...
# Name: description, dtype: object
# 231    traverse jkt sun set air cold three rugged mil...
# 142    traverse jkt training routine number bicycle i...
# Name: description, dtype: object
# 241    print bibiana top athletic bibiana tops racerb...
# 221    solid bibiana top athletic bibiana tops racerb...
# Name: description, dtype: object
# 242    print boucau halter top boucau soft ties neck ...
# 251    solid boucau halter top boucau soft ties neck ...
# Name: description, dtype: object
# 243    print kupala top fixed triangle bikini top kup...
# 252    solid kupala top fixed triangle bikini top kup...
# Name: description, dtype: object
# 244    runshade tshirt backcountry anyplace moves com...
# 347    runshade tshirt theres long trail ahead youre ...
# Name: description, dtype: object
# 246    serenity tights soft stretchy unrestricted mob...
# 214    serenity tights long soft stretchy unrestricte...
# Name: description, dtype: object
# 251    solid boucau halter top boucau soft ties neck ...
# 242    print boucau halter top boucau soft ties neck ...
# Name: description, dtype: object
# 252    solid kupala top fixed triangle bikini top kup...
# 243    print kupala top fixed triangle bikini top kup...
# Name: description, dtype: object
# 254    solid sunamee btm stayput sunamees fit straigh...
# 261    print sunamee btm stayput sunamees fit straigh...
# Name: description, dtype: object
# 259    merino crew lightest merino layer silkysoft ye...
# 199    merino graphic tshirt feels good laugh lightes...
# Name: description, dtype: object
# 259    merino crew lightest merino layer silkysoft ye...
# 200    merino tank finespun cool enough lower tempera...
# Name: description, dtype: object
# 259    merino crew lightest merino layer silkysoft ye...
# 264    merino tshirt soft worth lingering lightest me...
# Name: description, dtype: object
# 261    print sunamee btm stayput sunamees fit straigh...
# 254    solid sunamee btm stayput sunamees fit straigh...
# Name: description, dtype: object
# 262    r fullzip jkt stretches breathes wicks warms w...
# 377    r fullzip jkt stretches breathes wicks warms w...
# Name: description, dtype: object
# 264    merino tshirt soft worth lingering lightest me...
# 199    merino graphic tshirt feels good laugh lightes...
# Name: description, dtype: object
# 264    merino tshirt soft worth lingering lightest me...
# 200    merino tank finespun cool enough lower tempera...
# Name: description, dtype: object
# 264    merino tshirt soft worth lingering lightest me...
# 259    merino crew lightest merino layer silkysoft ye...
# Name: description, dtype: object
# 265    merino bottoms thankfully dry warm forward pro...
# 405    merino bottoms stopandgo pace like alpine clim...
# Name: description, dtype: object
# 266    storm light jkt emerging classic inspired orig...
# 385    storm light jkt emerging classic inspired orig...
# Name: description, dtype: object
# 267    stretch ascent jkt simple stretchy lightweight...
# 386    stretch ascent jkt simple stretchy lightweight...
# Name: description, dtype: object
# 273    torrentshell jkt tropical rain forests share l...
# 326    torrentshell jkt tropical rain forests share l...
# Name: description, dtype: object
# 274    torrentshell pants theyre lightweight waterpro...
# 140    torrentshell pants theyre lightweight waterpro...
# Name: description, dtype: object
# 279    nano puff po versatile piece insulation make n...
# 457    nano puff po already cult classic ambassadors ...
# Name: description, dtype: object
# 280    nine trails jkt nine trails jacket women whose...
# 95     nine trails jkt somewhere bridger ridge run no...
# Name: description, dtype: object
# 281    sweater vest impossible confuse sweater vests ...
# 34     sweater vest impossible confuse sweater vests ...
# Name: description, dtype: object
# 285    freedom roam tshirt global warming habitat des...
# 491    freedom roam tshirt global warming habitat des...
# Name: description, dtype: object
# 290    print adour btm adours slightly scooped lowris...
# 218    solid adour btm adours feature scooped lowrise...
# Name: description, dtype: object
# 292    houdini fullzip jkt see dont like sun blustery...
# 404    houdini fullzip jkt see dont like sun blustery...
# Name: description, dtype: object
# 304    intercontinental pants reg youll like flatteri...
# 187    intercontinental pants long youll like flatter...
# Name: description, dtype: object
# 307    alpine wind jkt high ridges steep ice anything...
# 4      alpine wind jkt high ridges steep ice anything...
# Name: description, dtype: object
# 326    torrentshell jkt tropical rain forests share l...
# 273    torrentshell jkt tropical rain forests share l...
# Name: description, dtype: object
# 333    live simply deer tshirt adaptability simply ma...
# 71     live simply deer tshirt adaptability simply ma...
# Name: description, dtype: object
# 334    live simply guitar tshirt live life unplugged ...
# 72     live simply guitar tshirt live life unplugged ...
# Name: description, dtype: object
# 339    cap graphic tshirt elegant union graceful desi...
# 19     cap graphic tshirt tee made lightestweight cap...
# Name: description, dtype: object
# 347    runshade tshirt theres long trail ahead youre ...
# 244    runshade tshirt backcountry anyplace moves com...
# Name: description, dtype: object
# 349    shop pants long home truck inside shop pants m...
# 117    shop pants reg home truck inside shop pants ma...
# Name: description, dtype: object
# 349    shop pants long home truck inside shop pants m...
# 118    shop pants short home truck inside shop pants ...
# Name: description, dtype: object
# 350    rain shadow pants light enough afterthought do...
# 106    rain shadow pants light enough afterthought do...
# Name: description, dtype: object
# 352    simple guide pants staple rock ice mixed climb...
# 216    simple guide pants trip patagonia one pair pan...
# Name: description, dtype: object
# 353    single shot single shot organizes daily necess...
# 463    daily grind fully padded shoulder bag keeps mo...
# Name: description, dtype: object
# 354    watermaster waders king blackberries barbwire ...
# 152    watermaster waders long blackberries barbwire ...
# Name: description, dtype: object
# 354    watermaster waders king blackberries barbwire ...
# 153    watermaster waders short blackberries barbwire...
# Name: description, dtype: object
# 354    watermaster waders king blackberries barbwire ...
# 366    watermaster waders reg blackberries barbwire b...
# Name: description, dtype: object
# 354    watermaster waders king blackberries barbwire ...
# 454    guidewater waders king built guidewater waders...
# Name: description, dtype: object
# 354    watermaster waders king blackberries barbwire ...
# 467    guidewater waders reg built guidewater waders ...
# Name: description, dtype: object
# 358    cap cap sleeve fastestdrying performance basel...
# 359    cap tshirt like sweet breeze long runs hot day...
# Name: description, dtype: object
# 359    cap tshirt like sweet breeze long runs hot day...
# 358    cap cap sleeve fastestdrying performance basel...
# Name: description, dtype: object
# 360    ss rashguard upf fabric shortsleeved rashguard...
# 76     ls rashguard upf fabric longsleeved rashguard ...
# Name: description, dtype: object
# 363    nine trails vest simplicity action vest protec...
# 209    nine trails vest simplicity action vest protec...
# Name: description, dtype: object
# 366    watermaster waders reg blackberries barbwire b...
# 152    watermaster waders long blackberries barbwire ...
# Name: description, dtype: object
# 366    watermaster waders reg blackberries barbwire b...
# 153    watermaster waders short blackberries barbwire...
# Name: description, dtype: object
# 366    watermaster waders reg blackberries barbwire b...
# 354    watermaster waders king blackberries barbwire ...
# Name: description, dtype: object
# 366    watermaster waders reg blackberries barbwire b...
# 454    guidewater waders king built guidewater waders...
# Name: description, dtype: object
# 366    watermaster waders reg blackberries barbwire b...
# 467    guidewater waders reg built guidewater waders ...
# Name: description, dtype: object
# 368    stand shorts theyve around plus years reenvisi...
# 369    stand shorts theyve around plus years reenvisi...
# Name: description, dtype: object
# 369    stand shorts theyve around plus years reenvisi...
# 368    stand shorts theyve around plus years reenvisi...
# Name: description, dtype: object
# 377    r fullzip jkt stretches breathes wicks warms w...
# 262    r fullzip jkt stretches breathes wicks warms w...
# Name: description, dtype: object
# 378    lw guide pants backcountry version immensely p...
# 383    lw guide pants backcountry version immensely p...
# Name: description, dtype: object
# 379    lw r jkt high deck warbonnet peak immaculate w...
# 81     lw r jkt high deck warbonnet peak immaculate w...
# Name: description, dtype: object
# 380    r jkt modern mountain staple adaptable r jacke...
# 210    r jkt modern mountain staple adaptable r jacke...
# Name: description, dtype: object
# 381    rain shadow jkt staying inside isnt way stay d...
# 211    rain shadow jkt staying inside isnt way stay d...
# Name: description, dtype: object
# 383    lw guide pants backcountry version immensely p...
# 378    lw guide pants backcountry version immensely p...
# Name: description, dtype: object
# 385    storm light jkt emerging classic inspired orig...
# 266    storm light jkt emerging classic inspired orig...
# Name: description, dtype: object
# 386    stretch ascent jkt simple stretchy lightweight...
# 267    stretch ascent jkt simple stretchy lightweight...
# Name: description, dtype: object
# 389    reg fit organic ctn jeansshort organic cotton ...
# 107    reg fit organic ctn jeanslong organic cotton d...
# Name: description, dtype: object
# 389    reg fit organic ctn jeansshort organic cotton ...
# 108    reg fit organic ctn jeansreg organic cotton de...
# Name: description, dtype: object
# 390    relax fit organic ctn jeanslong everyday goto ...
# 109    relax fit organic ctn jeansshor everyday goto ...
# Name: description, dtype: object
# 390    relax fit organic ctn jeanslong everyday goto ...
# 391    relax fit organic ctn jeansreg everyday goto r...
# Name: description, dtype: object
# 391    relax fit organic ctn jeansreg everyday goto r...
# 109    relax fit organic ctn jeansshor everyday goto ...
# Name: description, dtype: object
# 391    relax fit organic ctn jeansreg everyday goto r...
# 390    relax fit organic ctn jeanslong everyday goto ...
# Name: description, dtype: object
# 397    marlwalker stalking coral flats tough feet eve...
# 112    riverwalker felt high water slick bedrock cobb...
# Name: description, dtype: object
# 397    marlwalker stalking coral flats tough feet eve...
# 113    riverwalker studded high water slick bedrock c...
# Name: description, dtype: object
# 397    marlwalker stalking coral flats tough feet eve...
# 419    riverwalker sticky high water slick bedrock co...
# Name: description, dtype: object
# 404    houdini fullzip jkt see dont like sun blustery...
# 292    houdini fullzip jkt see dont like sun blustery...
# Name: description, dtype: object
# 405    merino bottoms stopandgo pace like alpine clim...
# 265    merino bottoms thankfully dry warm forward pro...
# Name: description, dtype: object
# 406    merino crew soft longsleeved tee work sweat bi...
# 87     merino tshirt bus ride tlachichuca packs bodie...
# Name: description, dtype: object
# 406    merino crew soft longsleeved tee work sweat bi...
# 88     merino polo feel bohemian look least get foot ...
# Name: description, dtype: object
# 406    merino crew soft longsleeved tee work sweat bi...
# 89     merino tshirt stay calm collected amid frenzy ...
# Name: description, dtype: object
# 415    micro puff vest many alpine shiverfests leave ...
# 203    micro puff vest many alpine shiverfests leave ...
# Name: description, dtype: object
# 419    riverwalker sticky high water slick bedrock co...
# 112    riverwalker felt high water slick bedrock cobb...
# Name: description, dtype: object
# 419    riverwalker sticky high water slick bedrock co...
# 113    riverwalker studded high water slick bedrock c...
# Name: description, dtype: object
# 419    riverwalker sticky high water slick bedrock co...
# 397    marlwalker stalking coral flats tough feet eve...
# Name: description, dtype: object
# 420    freewheeler max like storage locker wheels cav...
# 41     freewheeler sturdy wheeled bag holds weeks wor...
# Name: description, dtype: object
# 431    girls live simply deer tshirt softwearing ring...
# 62     flying fish tshirt softwearing ringspun organi...
# Name: description, dtype: object
# 431    girls live simply deer tshirt softwearing ring...
# 63     gpiw classic tshirt softwearing ringspun organ...
# Name: description, dtype: object
# 431    girls live simply deer tshirt softwearing ring...
# 64     live simply guitar tshirt softwearing ringspun...
# Name: description, dtype: object
# 431    girls live simply deer tshirt softwearing ring...
# 432    girls live simply seal tshirt softwearing ring...
# Name: description, dtype: object
# 432    girls live simply seal tshirt softwearing ring...
# 57     logo tshirt softwearing ringspun organic cotto...
# Name: description, dtype: object
# 432    girls live simply seal tshirt softwearing ring...
# 62     flying fish tshirt softwearing ringspun organi...
# Name: description, dtype: object
# 432    girls live simply seal tshirt softwearing ring...
# 63     gpiw classic tshirt softwearing ringspun organ...
# Name: description, dtype: object
# 432    girls live simply seal tshirt softwearing ring...
# 64     live simply guitar tshirt softwearing ringspun...
# Name: description, dtype: object
# 432    girls live simply seal tshirt softwearing ring...
# 431    girls live simply deer tshirt softwearing ring...
# Name: description, dtype: object
# 437    guide jkt sharp granite sticky verglas untrack...
# 183    guide jkt sharp granite sticky verglas untrack...
# Name: description, dtype: object
# 440    cap crew capilene versatile fastestwicking per...
# 442    cap crew fundamental funhog lifestyle crew non...
# Name: description, dtype: object
# 442    cap crew fundamental funhog lifestyle crew non...
# 440    cap crew capilene versatile fastestwicking per...
# Name: description, dtype: object
# 443    guidewater pants drift boat flats skiff spring...
# 51     guidewater shorts everything love guidewater p...
# Name: description, dtype: object
# 451    compound cargo pants short ultimate doeverythi...
# 26     compound cargo pants long ultimate doeverythin...
# Name: description, dtype: object
# 451    compound cargo pants short ultimate doeverythi...
# 27     compound cargo pants reg ultimate doeverything...
# Name: description, dtype: object
# 454    guidewater waders king built guidewater waders...
# 152    watermaster waders long blackberries barbwire ...
# Name: description, dtype: object
# 454    guidewater waders king built guidewater waders...
# 153    watermaster waders short blackberries barbwire...
# Name: description, dtype: object
# 454    guidewater waders king built guidewater waders...
# 354    watermaster waders king blackberries barbwire ...
# Name: description, dtype: object
# 454    guidewater waders king built guidewater waders...
# 366    watermaster waders reg blackberries barbwire b...
# Name: description, dtype: object
# 454    guidewater waders king built guidewater waders...
# 467    guidewater waders reg built guidewater waders ...
# Name: description, dtype: object
# 455    critical mass built twowheeled commute critica...
# 485    half mass sized riding bike finely tuned hold ...
# Name: description, dtype: object
# 457    nano puff po already cult classic ambassadors ...
# 279    nano puff po versatile piece insulation make n...
# Name: description, dtype: object
# 461    custodian pants reg graveyard shift advantages...
# 31     custodian pants long graveyard shift advantage...
# Name: description, dtype: object
# 461    custodian pants reg graveyard shift advantages...
# 462    custodian pants short graveyard shift advantag...
# Name: description, dtype: object
# 462    custodian pants short graveyard shift advantag...
# 31     custodian pants long graveyard shift advantage...
# Name: description, dtype: object
# 462    custodian pants short graveyard shift advantag...
# 461    custodian pants reg graveyard shift advantages...
# Name: description, dtype: object
# 463    daily grind fully padded shoulder bag keeps mo...
# 353    single shot single shot organizes daily necess...
# Name: description, dtype: object
# 467    guidewater waders reg built guidewater waders ...
# 152    watermaster waders long blackberries barbwire ...
# Name: description, dtype: object
# 467    guidewater waders reg built guidewater waders ...
# 153    watermaster waders short blackberries barbwire...
# Name: description, dtype: object
# 467    guidewater waders reg built guidewater waders ...
# 354    watermaster waders king blackberries barbwire ...
# Name: description, dtype: object
# 467    guidewater waders reg built guidewater waders ...
# 366    watermaster waders reg blackberries barbwire b...
# Name: description, dtype: object
# 467    guidewater waders reg built guidewater waders ...
# 454    guidewater waders king built guidewater waders...
# Name: description, dtype: object
# 472    sweater theres much see feet chasm view bivy v...
# 178    sweater theres much see feet chasm view bivy v...
# Name: description, dtype: object
# 480    duck pants reg essential wear splitting logs d...
# 36     duck pants long essential wear splitting logs ...
# Name: description, dtype: object
# 480    duck pants reg essential wear splitting logs d...
# 481    duck pants short essential wear splitting logs...
# Name: description, dtype: object
# 481    duck pants short essential wear splitting logs...
# 36     duck pants long essential wear splitting logs ...
# Name: description, dtype: object
# 481    duck pants short essential wear splitting logs...
# 480    duck pants reg essential wear splitting logs d...
# Name: description, dtype: object
# 485    half mass sized riding bike finely tuned hold ...
# 455    critical mass built twowheeled commute critica...
# Name: description, dtype: object
# 491    freedom roam tshirt global warming habitat des...
# 285    freedom roam tshirt global warming habitat des...
# Name: description, dtype: object
# 495    cap bottoms cut loose maddening crowds search ...
# 172    cap bottoms simulclimbing final pitches beat d...
# Name: description, dtype: object
